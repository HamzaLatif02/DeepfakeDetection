# %% [markdown]
# Jupyter notebook used to train the model 'se_resnet34' but using a dataset 2.5 times larger.
# The setup of the notebook is inspired from what i have used in the IN3060: Computer Vision module.
# I have used Google Colaboratory to train the model.
# Follow the README file for instructions on how to setup the Google Drive file to be able to replicate this.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the project folder
# Example: GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/DeepfakeDetectionFolder'

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'DeepfakeDetectionModel'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['Dataset', 'Code', 'Models', 'resnet34_train.ipynb', 'resnet50_train.ipynb', 'resnet101_train.ipynb', 'resnet152_train.ipynb', 'compare_resnet_models.ipynb', 'se_resnet34_train.ipynb', 'se_resnet50_train.ipynb', 'se_resnet101_train.ipynb', 'se_resnet152_train.ipynb', 'compare_se_resnet_models.ipynb', 'resnet152_train_v2.ipynb', 'se_resnet34_train_v2.ipynb']

# %%
# set paths to dataset and code folder
DATASET_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Dataset', 'Dataset_Cropped_V2')
CODE_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Code')
print(os.listdir(DATASET_FOLDER))
print(os.listdir(CODE_FOLDER))
# Out:
# ['.DS_Store', 'test', 'train']
# ['resnet34.py', '__pycache__', 'calculate_mean_std.py', 'resnet50.py', 'resnet152.py', 'resnet101.py', 'se_resnet34.py', 'se_resnet50.py', 'se_resnet101.py', 'se_resnet152.py']

# %%
# necessary to be able to load the functions from the code folder
# %load_ext autoreload
# %autoreload 2

# %%
# append code folder to system
import sys
sys.path.append(CODE_FOLDER)

# %%
# import model and function to calculate mean and std values
from se_resnet34 import Se_ResNet34
from calculate_mean_std import calculate_mean_std

# %%
# setup train dataset path
train_dataset_path = os.path.join(DATASET_FOLDER, 'train')

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# check if cpu or gpu is being used
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
# calcualte average mean and std value to be used after to normalize the training dataset
stats_transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.ToTensor(),
])

stats_dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=stats_transform)

stats_loader = DataLoader(stats_dataset, batch_size=4, shuffle=True, num_workers=2)

calc_mean, calc_std = calculate_mean_std(stats_loader)

print(f'Mean: {calc_mean}')
print(f'Std: {calc_std}')
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Mean: tensor([0.5507, 0.4151, 0.3802])
# Std: tensor([0.2163, 0.1709, 0.1608])

# %%
# apply transformations to the training dataset
transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    transforms.Normalize(mean=calc_mean, std=calc_std),
])

dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=transform)

# split dataset into training and testing using 80/20 split
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="training", seed=123)
# Out:
# Found 8017 files belonging to 3 classes.
# Using 6414 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="validation", seed=123)
# Out:
# Found 8017 files belonging to 3 classes.
# Using 1603 files for validation.

# %%
model = Se_ResNet34()

# %%
# declare loss parameter and optimizer used
criterion = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model.compile(optimizer=optimizer, loss=criterion, metrics=['accuracy'])

# %%
# train the model using 100 epochs
num_epochs = 100
history = model.fit(train_ds, epochs=num_epochs, validation_data=val_ds)
# Out:
# Epoch 1/100
# 201/201 [==============================] - 139s 376ms/step - loss: 1.8854 - accuracy: 0.3527 - val_loss: 1.1304 - val_accuracy: 0.3631
# Epoch 2/100
# 201/201 [==============================] - 74s 364ms/step - loss: 1.1161 - accuracy: 0.3617 - val_loss: 1.1047 - val_accuracy: 0.3631
# Epoch 3/100
# 201/201 [==============================] - 76s 373ms/step - loss: 1.1042 - accuracy: 0.3573 - val_loss: 1.0905 - val_accuracy: 0.3787
# Epoch 4/100
# 201/201 [==============================] - 75s 371ms/step - loss: 1.0898 - accuracy: 0.3926 - val_loss: 1.0871 - val_accuracy: 0.3886
# Epoch 5/100
# 201/201 [==============================] - 76s 374ms/step - loss: 1.0921 - accuracy: 0.3835 - val_loss: 1.1115 - val_accuracy: 0.3805
# Epoch 6/100
# 201/201 [==============================] - 76s 374ms/step - loss: 1.0921 - accuracy: 0.3960 - val_loss: 2.0748 - val_accuracy: 0.3518
# Epoch 7/100
# 201/201 [==============================] - 78s 386ms/step - loss: 1.0845 - accuracy: 0.3996 - val_loss: 2.1839 - val_accuracy: 0.3656
# Epoch 8/100
# 201/201 [==============================] - 76s 375ms/step - loss: 1.0838 - accuracy: 0.3951 - val_loss: 4.1201 - val_accuracy: 0.3001
# Epoch 9/100
# 201/201 [==============================] - 76s 375ms/step - loss: 1.0614 - accuracy: 0.4147 - val_loss: 1.0980 - val_accuracy: 0.4005
# Epoch 10/100
# 201/201 [==============================] - 78s 386ms/step - loss: 1.0386 - accuracy: 0.4348 - val_loss: 1.0514 - val_accuracy: 0.4267
# Epoch 11/100
# 201/201 [==============================] - 75s 367ms/step - loss: 1.0152 - accuracy: 0.4546 - val_loss: 1.0362 - val_accuracy: 0.4448
# Epoch 12/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.9846 - accuracy: 0.4846 - val_loss: 1.0414 - val_accuracy: 0.5053
# Epoch 13/100
# 201/201 [==============================] - 75s 368ms/step - loss: 0.9568 - accuracy: 0.5145 - val_loss: 0.9686 - val_accuracy: 0.5097
# Epoch 14/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.9002 - accuracy: 0.5613 - val_loss: 0.9668 - val_accuracy: 0.5321
# Epoch 15/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.8464 - accuracy: 0.6017 - val_loss: 0.8963 - val_accuracy: 0.5608
# Epoch 16/100
# 201/201 [==============================] - 78s 386ms/step - loss: 0.8097 - accuracy: 0.6324 - val_loss: 0.8989 - val_accuracy: 0.5627
# Epoch 17/100
# 201/201 [==============================] - 76s 374ms/step - loss: 0.7497 - accuracy: 0.6656 - val_loss: 0.8068 - val_accuracy: 0.6363
# Epoch 18/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.7036 - accuracy: 0.6829 - val_loss: 0.8187 - val_accuracy: 0.6376
# Epoch 19/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.6500 - accuracy: 0.7166 - val_loss: 0.8279 - val_accuracy: 0.6213
# Epoch 20/100
# 201/201 [==============================] - 78s 386ms/step - loss: 0.6125 - accuracy: 0.7387 - val_loss: 1.5182 - val_accuracy: 0.4735
# Epoch 21/100
# 201/201 [==============================] - 76s 373ms/step - loss: 0.5747 - accuracy: 0.7562 - val_loss: 1.3826 - val_accuracy: 0.5477
# Epoch 22/100
# 201/201 [==============================] - 75s 368ms/step - loss: 0.5112 - accuracy: 0.7783 - val_loss: 0.7239 - val_accuracy: 0.7018
# Epoch 23/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.4663 - accuracy: 0.8006 - val_loss: 0.9227 - val_accuracy: 0.6625
# Epoch 24/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.4180 - accuracy: 0.8241 - val_loss: 0.8123 - val_accuracy: 0.6769
# Epoch 25/100
# 201/201 [==============================] - 76s 376ms/step - loss: 0.3781 - accuracy: 0.8413 - val_loss: 0.8380 - val_accuracy: 0.6943
# Epoch 26/100
# 201/201 [==============================] - 75s 369ms/step - loss: 0.3355 - accuracy: 0.8603 - val_loss: 0.8993 - val_accuracy: 0.6968
# Epoch 27/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.2909 - accuracy: 0.8761 - val_loss: 0.9772 - val_accuracy: 0.6925
# Epoch 28/100
# 201/201 [==============================] - 76s 375ms/step - loss: 0.2754 - accuracy: 0.8842 - val_loss: 0.8047 - val_accuracy: 0.7143
# Epoch 29/100
# 201/201 [==============================] - 76s 376ms/step - loss: 0.2268 - accuracy: 0.9077 - val_loss: 0.8181 - val_accuracy: 0.7311
# Epoch 30/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.2006 - accuracy: 0.9188 - val_loss: 0.8311 - val_accuracy: 0.7361
# Epoch 31/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.1996 - accuracy: 0.9197 - val_loss: 0.8660 - val_accuracy: 0.7261
# Epoch 32/100
# 201/201 [==============================] - 79s 390ms/step - loss: 0.1880 - accuracy: 0.9249 - val_loss: 0.8495 - val_accuracy: 0.7392
# Epoch 33/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.1632 - accuracy: 0.9359 - val_loss: 0.8938 - val_accuracy: 0.7567
# Epoch 34/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.1513 - accuracy: 0.9403 - val_loss: 1.0609 - val_accuracy: 0.7374
# Epoch 35/100
# 201/201 [==============================] - 75s 369ms/step - loss: 0.1580 - accuracy: 0.9387 - val_loss: 1.0755 - val_accuracy: 0.7037
# Epoch 36/100
# 201/201 [==============================] - 76s 374ms/step - loss: 0.1465 - accuracy: 0.9386 - val_loss: 0.9936 - val_accuracy: 0.7480
# Epoch 37/100
# 201/201 [==============================] - 75s 367ms/step - loss: 0.1265 - accuracy: 0.9500 - val_loss: 1.0443 - val_accuracy: 0.7424
# Epoch 38/100
# 201/201 [==============================] - 76s 374ms/step - loss: 0.1063 - accuracy: 0.9601 - val_loss: 1.0862 - val_accuracy: 0.7480
# Epoch 39/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.1225 - accuracy: 0.9534 - val_loss: 0.9929 - val_accuracy: 0.7449
# Epoch 40/100
# 201/201 [==============================] - 75s 368ms/step - loss: 0.1255 - accuracy: 0.9524 - val_loss: 0.9592 - val_accuracy: 0.7536
# Epoch 41/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.1207 - accuracy: 0.9517 - val_loss: 1.3680 - val_accuracy: 0.6818
# Epoch 42/100
# 201/201 [==============================] - 79s 388ms/step - loss: 0.1111 - accuracy: 0.9557 - val_loss: 1.1443 - val_accuracy: 0.7342
# Epoch 43/100
# 201/201 [==============================] - 76s 376ms/step - loss: 0.0995 - accuracy: 0.9606 - val_loss: 1.0349 - val_accuracy: 0.7342
# Epoch 44/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.1047 - accuracy: 0.9579 - val_loss: 1.0787 - val_accuracy: 0.7505
# Epoch 45/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0884 - accuracy: 0.9637 - val_loss: 1.2281 - val_accuracy: 0.7486
# Epoch 46/100
# 201/201 [==============================] - 75s 367ms/step - loss: 0.1265 - accuracy: 0.9504 - val_loss: 1.1256 - val_accuracy: 0.7243
# Epoch 47/100
# 201/201 [==============================] - 79s 388ms/step - loss: 0.0914 - accuracy: 0.9616 - val_loss: 1.1246 - val_accuracy: 0.7467
# Epoch 48/100
# 201/201 [==============================] - 79s 391ms/step - loss: 0.0952 - accuracy: 0.9620 - val_loss: 1.2458 - val_accuracy: 0.7311
# Epoch 49/100
# 201/201 [==============================] - 75s 370ms/step - loss: 0.0960 - accuracy: 0.9604 - val_loss: 1.7886 - val_accuracy: 0.6731
# Epoch 50/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.0960 - accuracy: 0.9621 - val_loss: 1.2950 - val_accuracy: 0.7143
# Epoch 51/100
# 201/201 [==============================] - 76s 375ms/step - loss: 0.0781 - accuracy: 0.9690 - val_loss: 1.4035 - val_accuracy: 0.7367
# Epoch 52/100
# 201/201 [==============================] - 74s 367ms/step - loss: 0.0691 - accuracy: 0.9737 - val_loss: 1.0766 - val_accuracy: 0.7611
# Epoch 53/100
# 201/201 [==============================] - 76s 376ms/step - loss: 0.0851 - accuracy: 0.9662 - val_loss: 1.4876 - val_accuracy: 0.7155
# Epoch 54/100
# 201/201 [==============================] - 78s 387ms/step - loss: 0.0768 - accuracy: 0.9684 - val_loss: 1.7045 - val_accuracy: 0.7031
# Epoch 55/100
# 201/201 [==============================] - 79s 388ms/step - loss: 0.0925 - accuracy: 0.9643 - val_loss: 1.0736 - val_accuracy: 0.7729
# Epoch 56/100
# 201/201 [==============================] - 76s 374ms/step - loss: 0.0817 - accuracy: 0.9682 - val_loss: 1.8932 - val_accuracy: 0.6818
# Epoch 57/100
# 201/201 [==============================] - 76s 376ms/step - loss: 0.0787 - accuracy: 0.9716 - val_loss: 1.5493 - val_accuracy: 0.7236
# Epoch 58/100
# 201/201 [==============================] - 76s 376ms/step - loss: 0.0760 - accuracy: 0.9707 - val_loss: 1.1145 - val_accuracy: 0.7661
# Epoch 59/100
# 201/201 [==============================] - 75s 367ms/step - loss: 0.0591 - accuracy: 0.9774 - val_loss: 1.5479 - val_accuracy: 0.7205
# Epoch 60/100
# 201/201 [==============================] - 75s 367ms/step - loss: 0.0744 - accuracy: 0.9722 - val_loss: 1.5321 - val_accuracy: 0.7168
# Epoch 61/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.0713 - accuracy: 0.9732 - val_loss: 1.2066 - val_accuracy: 0.7517
# Epoch 62/100
# 201/201 [==============================] - 75s 368ms/step - loss: 0.0647 - accuracy: 0.9735 - val_loss: 1.0858 - val_accuracy: 0.7748
# Epoch 63/100
# 201/201 [==============================] - 76s 373ms/step - loss: 0.0654 - accuracy: 0.9751 - val_loss: 2.4901 - val_accuracy: 0.6257
# Epoch 64/100
# 201/201 [==============================] - 76s 375ms/step - loss: 0.0862 - accuracy: 0.9702 - val_loss: 1.3400 - val_accuracy: 0.7430
# Epoch 65/100
# 201/201 [==============================] - 74s 366ms/step - loss: 0.0628 - accuracy: 0.9751 - val_loss: 1.9678 - val_accuracy: 0.7043
# Epoch 66/100
# 201/201 [==============================] - 75s 370ms/step - loss: 0.0630 - accuracy: 0.9751 - val_loss: 1.6818 - val_accuracy: 0.7155
# Epoch 67/100
# 201/201 [==============================] - 75s 366ms/step - loss: 0.0663 - accuracy: 0.9741 - val_loss: 1.5266 - val_accuracy: 0.7274
# Epoch 68/100
# 201/201 [==============================] - 75s 368ms/step - loss: 0.0652 - accuracy: 0.9751 - val_loss: 1.2338 - val_accuracy: 0.7617
# Epoch 69/100
# 201/201 [==============================] - 75s 370ms/step - loss: 0.0607 - accuracy: 0.9769 - val_loss: 1.1738 - val_accuracy: 0.7623
# Epoch 70/100
# 201/201 [==============================] - 76s 374ms/step - loss: 0.0626 - accuracy: 0.9766 - val_loss: 1.2522 - val_accuracy: 0.7679
# Epoch 71/100
# 201/201 [==============================] - 79s 388ms/step - loss: 0.0617 - accuracy: 0.9760 - val_loss: 1.1516 - val_accuracy: 0.7679
# Epoch 72/100
# 201/201 [==============================] - 79s 388ms/step - loss: 0.0629 - accuracy: 0.9765 - val_loss: 1.1453 - val_accuracy: 0.7561
# Epoch 73/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.0526 - accuracy: 0.9794 - val_loss: 1.3237 - val_accuracy: 0.7473
# Epoch 74/100
# 201/201 [==============================] - 75s 367ms/step - loss: 0.0637 - accuracy: 0.9761 - val_loss: 1.4066 - val_accuracy: 0.7542
# Epoch 75/100
# 201/201 [==============================] - 77s 377ms/step - loss: 0.0604 - accuracy: 0.9755 - val_loss: 1.2004 - val_accuracy: 0.7449
# Epoch 76/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0703 - accuracy: 0.9727 - val_loss: 1.2476 - val_accuracy: 0.7280
# Epoch 77/100
# 201/201 [==============================] - 78s 387ms/step - loss: 0.0524 - accuracy: 0.9780 - val_loss: 1.3609 - val_accuracy: 0.7380
# Epoch 78/100
# 201/201 [==============================] - 76s 375ms/step - loss: 0.0510 - accuracy: 0.9790 - val_loss: 1.1923 - val_accuracy: 0.7580
# Epoch 79/100
# 201/201 [==============================] - 78s 386ms/step - loss: 0.0493 - accuracy: 0.9811 - val_loss: 1.4277 - val_accuracy: 0.7361
# Epoch 80/100
# 201/201 [==============================] - 75s 369ms/step - loss: 0.0440 - accuracy: 0.9822 - val_loss: 1.2763 - val_accuracy: 0.7654
# Epoch 81/100
# 201/201 [==============================] - 76s 374ms/step - loss: 0.0636 - accuracy: 0.9757 - val_loss: 1.2243 - val_accuracy: 0.7511
# Epoch 82/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0577 - accuracy: 0.9766 - val_loss: 1.1767 - val_accuracy: 0.7573
# Epoch 83/100
# 201/201 [==============================] - 75s 371ms/step - loss: 0.0676 - accuracy: 0.9746 - val_loss: 1.2215 - val_accuracy: 0.7417
# Epoch 84/100
# 201/201 [==============================] - 75s 369ms/step - loss: 0.0591 - accuracy: 0.9777 - val_loss: 1.2675 - val_accuracy: 0.7436
# Epoch 85/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0493 - accuracy: 0.9790 - val_loss: 1.1788 - val_accuracy: 0.7642
# Epoch 86/100
# 201/201 [==============================] - 79s 388ms/step - loss: 0.0436 - accuracy: 0.9829 - val_loss: 1.4424 - val_accuracy: 0.7611
# Epoch 87/100
# 201/201 [==============================] - 75s 370ms/step - loss: 0.0539 - accuracy: 0.9804 - val_loss: 1.3429 - val_accuracy: 0.7374
# Epoch 88/100
# 201/201 [==============================] - 76s 377ms/step - loss: 0.0365 - accuracy: 0.9839 - val_loss: 1.4142 - val_accuracy: 0.7355
# Epoch 89/100
# 201/201 [==============================] - 76s 375ms/step - loss: 0.0467 - accuracy: 0.9833 - val_loss: 1.4153 - val_accuracy: 0.7392
# Epoch 90/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0477 - accuracy: 0.9811 - val_loss: 1.4510 - val_accuracy: 0.7274
# Epoch 91/100
# 201/201 [==============================] - 76s 373ms/step - loss: 0.0519 - accuracy: 0.9793 - val_loss: 1.3987 - val_accuracy: 0.7442
# Epoch 92/100
# 201/201 [==============================] - 75s 372ms/step - loss: 0.0729 - accuracy: 0.9751 - val_loss: 1.1678 - val_accuracy: 0.7642
# Epoch 93/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0500 - accuracy: 0.9802 - val_loss: 1.3962 - val_accuracy: 0.7555
# Epoch 94/100
# 201/201 [==============================] - 76s 371ms/step - loss: 0.0535 - accuracy: 0.9804 - val_loss: 1.3907 - val_accuracy: 0.7261
# Epoch 95/100
# 201/201 [==============================] - 76s 372ms/step - loss: 0.0447 - accuracy: 0.9839 - val_loss: 1.2513 - val_accuracy: 0.7754
# Epoch 96/100
# 201/201 [==============================] - 75s 370ms/step - loss: 0.0322 - accuracy: 0.9869 - val_loss: 1.4247 - val_accuracy: 0.7823
# Epoch 97/100
# 201/201 [==============================] - 76s 375ms/step - loss: 0.0445 - accuracy: 0.9816 - val_loss: 1.7076 - val_accuracy: 0.7542
# Epoch 98/100
# 201/201 [==============================] - 78s 386ms/step - loss: 0.0350 - accuracy: 0.9858 - val_loss: 1.4970 - val_accuracy: 0.7760
# Epoch 99/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.0462 - accuracy: 0.9824 - val_loss: 1.5560 - val_accuracy: 0.7642
# Epoch 100/100
# 201/201 [==============================] - 79s 387ms/step - loss: 0.0480 - accuracy: 0.9821 - val_loss: 1.5651 - val_accuracy: 0.7455

# %%
# save the model so it does not have to be trained again
save_path = os.path.join(GOOGLE_DRIVE_PATH, 'Models')
model.save(os.path.join(save_path, 'se_resnet34_v2'))

# %%
# get accuracy and loss values
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(acc) + 1)

# plot training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()
