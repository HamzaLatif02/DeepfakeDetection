# %% [markdown]
# Jupyter notebook used to train the model 'se_resnet101'.
# The setup of the notebook is inspired from what i have used in the IN3060: Computer Vision module.
# I have used Google Colaboratory to train the model.
# Follow the README file for instructions on how to setup the Google Drive file to be able to replicate this.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the project folder
# Example: GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/DeepfakeDetectionFolder'

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'DeepfakeDetectionModel'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['Dataset', 'Code', 'Models', 'resnet34_train.ipynb', 'resnet50_train.ipynb', 'resnet101_train.ipynb', 'resnet152_train.ipynb', 'compare_resnet_models.ipynb', 'se_resnet34_train.ipynb', 'se_resnet50_train.ipynb', 'Copy of resnet101_train.ipynb']

# %%
# set paths to dataset and code folder
DATASET_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Dataset', 'Dataset_Cropped')
CODE_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Code')
print(os.listdir(DATASET_FOLDER))
print(os.listdir(CODE_FOLDER))
# Out:
# ['.DS_Store', 'train', 'test']
# ['resnet34.py', '__pycache__', 'calculate_mean_std.py', 'resnet50.py', 'resnet152.py', 'resnet101.py', 'se_resnet34.py', 'se_resnet50.py', 'se_resnet101.py', 'se_resnet152.py']

# %%
# necessary to be able to load the functions from the code folder
# %load_ext autoreload
# %autoreload 2

# %%
# append code folder to system
import sys
sys.path.append(CODE_FOLDER)

# %%
# import model and function to calculate mean and std values
from se_resnet101 import Se_ResNet101
from calculate_mean_std import calculate_mean_std

# %%
# setup train dataset path
train_dataset_path = os.path.join(DATASET_FOLDER, 'train')

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# check if cpu or gpu is being used
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
# calcualte average mean and std value to be used after to normalize the training dataset
stats_transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.ToTensor(),
])

stats_dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=stats_transform)

stats_loader = DataLoader(stats_dataset, batch_size=4, shuffle=True, num_workers=2)

calc_mean, calc_std = calculate_mean_std(stats_loader)

print(f'Mean: {calc_mean}')
print(f'Std: {calc_std}')
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Mean: tensor([0.5498, 0.4155, 0.3822])
# Std: tensor([0.2164, 0.1714, 0.1615])

# %%
# apply transformations to the training dataset
transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    transforms.Normalize(mean=calc_mean, std=calc_std),
])

dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=transform)

# split dataset into training and testing using 80/20 split
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="training", seed=123)
# Out:
# Found 2948 files belonging to 3 classes.
# Using 2359 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="validation", seed=123)
# Out:
# Found 2948 files belonging to 3 classes.
# Using 589 files for validation.

# %%
model = Se_ResNet101()

# %%
# declare loss parameter and optimizer used
criterion = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model.compile(optimizer=optimizer, loss=criterion, metrics=['accuracy'])

# %%
# train the model using 100 epochs
num_epochs = 100
history = model.fit(train_ds, epochs=num_epochs, validation_data=val_ds)
# Out:
# Epoch 1/100
# 74/74 [==============================] - 145s 741ms/step - loss: 10.1621 - accuracy: 0.3226 - val_loss: 322.6504 - val_accuracy: 0.3514
# Epoch 2/100
# 74/74 [==============================] - 44s 593ms/step - loss: 2.8287 - accuracy: 0.3425 - val_loss: 3.4286 - val_accuracy: 0.3497
# Epoch 3/100
# 74/74 [==============================] - 44s 596ms/step - loss: 1.9682 - accuracy: 0.3268 - val_loss: 1338.0444 - val_accuracy: 0.3192
# Epoch 4/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.4073 - accuracy: 0.3531 - val_loss: 30.6441 - val_accuracy: 0.3463
# Epoch 5/100
# 74/74 [==============================] - 44s 596ms/step - loss: 1.3216 - accuracy: 0.3514 - val_loss: 1.1865 - val_accuracy: 0.3311
# Epoch 6/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.2519 - accuracy: 0.3463 - val_loss: 1.4891 - val_accuracy: 0.3514
# Epoch 7/100
# 74/74 [==============================] - 45s 598ms/step - loss: 1.1574 - accuracy: 0.3663 - val_loss: 1.0940 - val_accuracy: 0.3345
# Epoch 8/100
# 74/74 [==============================] - 44s 596ms/step - loss: 1.2007 - accuracy: 0.3629 - val_loss: 1.2124 - val_accuracy: 0.3328
# Epoch 9/100
# 74/74 [==============================] - 44s 596ms/step - loss: 1.2102 - accuracy: 0.3786 - val_loss: 34.7584 - val_accuracy: 0.3531
# Epoch 10/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.1931 - accuracy: 0.3858 - val_loss: 4.6822 - val_accuracy: 0.4024
# Epoch 11/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.1449 - accuracy: 0.3985 - val_loss: 1.5042 - val_accuracy: 0.3956
# Epoch 12/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.1002 - accuracy: 0.4260 - val_loss: 3.3019 - val_accuracy: 0.3888
# Epoch 13/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.0892 - accuracy: 0.4375 - val_loss: 1.0976 - val_accuracy: 0.4177
# Epoch 14/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.0945 - accuracy: 0.4324 - val_loss: 1.1199 - val_accuracy: 0.3922
# Epoch 15/100
# 74/74 [==============================] - 44s 597ms/step - loss: 1.0645 - accuracy: 0.4481 - val_loss: 1.1136 - val_accuracy: 0.3922
# Epoch 16/100
# 74/74 [==============================] - 45s 599ms/step - loss: 1.0373 - accuracy: 0.4714 - val_loss: 1.2146 - val_accuracy: 0.3854
# Epoch 17/100
# 74/74 [==============================] - 45s 599ms/step - loss: 1.0357 - accuracy: 0.4676 - val_loss: 1.1094 - val_accuracy: 0.3854
# Epoch 18/100
# 74/74 [==============================] - 45s 599ms/step - loss: 1.0219 - accuracy: 0.4727 - val_loss: 1.0723 - val_accuracy: 0.3837
# Epoch 19/100
# 74/74 [==============================] - 45s 599ms/step - loss: 1.0038 - accuracy: 0.4939 - val_loss: 1.1060 - val_accuracy: 0.4007
# Epoch 20/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.9962 - accuracy: 0.4985 - val_loss: 1.0985 - val_accuracy: 0.4075
# Epoch 21/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.9873 - accuracy: 0.5108 - val_loss: 1.1017 - val_accuracy: 0.4007
# Epoch 22/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.9639 - accuracy: 0.5278 - val_loss: 1.1042 - val_accuracy: 0.3837
# Epoch 23/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.9520 - accuracy: 0.5295 - val_loss: 1.1015 - val_accuracy: 0.4092
# Epoch 24/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.9417 - accuracy: 0.5447 - val_loss: 1.1145 - val_accuracy: 0.3803
# Epoch 25/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.9436 - accuracy: 0.5392 - val_loss: 1.1724 - val_accuracy: 0.4041
# Epoch 26/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.9089 - accuracy: 0.5549 - val_loss: 1.1089 - val_accuracy: 0.3871
# Epoch 27/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.9112 - accuracy: 0.5579 - val_loss: 1.9496 - val_accuracy: 0.3871
# Epoch 28/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.8830 - accuracy: 0.5977 - val_loss: 1.1467 - val_accuracy: 0.4177
# Epoch 29/100
# 74/74 [==============================] - 45s 605ms/step - loss: 0.8747 - accuracy: 0.5803 - val_loss: 1.1118 - val_accuracy: 0.4024
# Epoch 30/100
# 74/74 [==============================] - 45s 605ms/step - loss: 0.8642 - accuracy: 0.5850 - val_loss: 1.1197 - val_accuracy: 0.4109
# Epoch 31/100
# 74/74 [==============================] - 45s 605ms/step - loss: 0.8289 - accuracy: 0.6045 - val_loss: 1.1378 - val_accuracy: 0.4109
# Epoch 32/100
# 74/74 [==============================] - 45s 606ms/step - loss: 0.8098 - accuracy: 0.6236 - val_loss: 1.4481 - val_accuracy: 0.4177
# Epoch 33/100
# 74/74 [==============================] - 45s 606ms/step - loss: 0.7971 - accuracy: 0.6299 - val_loss: 1.1688 - val_accuracy: 0.4499
# Epoch 34/100
# 74/74 [==============================] - 45s 606ms/step - loss: 0.7739 - accuracy: 0.6431 - val_loss: 1.1765 - val_accuracy: 0.4143
# Epoch 35/100
# 74/74 [==============================] - 45s 607ms/step - loss: 0.7378 - accuracy: 0.6757 - val_loss: 1.2520 - val_accuracy: 0.4075
# Epoch 36/100
# 74/74 [==============================] - 45s 606ms/step - loss: 0.8033 - accuracy: 0.6282 - val_loss: 25.9628 - val_accuracy: 0.4024
# Epoch 37/100
# 74/74 [==============================] - 45s 606ms/step - loss: 0.8427 - accuracy: 0.5943 - val_loss: 1.4422 - val_accuracy: 0.4635
# Epoch 38/100
# 74/74 [==============================] - 45s 606ms/step - loss: 0.7746 - accuracy: 0.6333 - val_loss: 1.0958 - val_accuracy: 0.4414
# Epoch 39/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.7176 - accuracy: 0.6617 - val_loss: 1.1819 - val_accuracy: 0.4414
# Epoch 40/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.6771 - accuracy: 0.6973 - val_loss: 1.2654 - val_accuracy: 0.4244
# Epoch 41/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.6641 - accuracy: 0.7024 - val_loss: 1.2090 - val_accuracy: 0.4346
# Epoch 42/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.6056 - accuracy: 0.7270 - val_loss: 1.3492 - val_accuracy: 0.4754
# Epoch 43/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.6050 - accuracy: 0.7359 - val_loss: 1.2748 - val_accuracy: 0.4329
# Epoch 44/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.5419 - accuracy: 0.7588 - val_loss: 1.3128 - val_accuracy: 0.4397
# Epoch 45/100
# 74/74 [==============================] - 44s 598ms/step - loss: 0.6504 - accuracy: 0.7113 - val_loss: 4.8356 - val_accuracy: 0.4652
# Epoch 46/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.6481 - accuracy: 0.7202 - val_loss: 1.2296 - val_accuracy: 0.4686
# Epoch 47/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.5551 - accuracy: 0.7639 - val_loss: 1.3426 - val_accuracy: 0.4448
# Epoch 48/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.4921 - accuracy: 0.7982 - val_loss: 1.3128 - val_accuracy: 0.4533
# Epoch 49/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.4752 - accuracy: 0.7961 - val_loss: 1.4183 - val_accuracy: 0.4414
# Epoch 50/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.4351 - accuracy: 0.8198 - val_loss: 1.3363 - val_accuracy: 0.4499
# Epoch 51/100
# 74/74 [==============================] - 45s 597ms/step - loss: 0.4108 - accuracy: 0.8317 - val_loss: 1.5286 - val_accuracy: 0.4890
# Epoch 52/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.4148 - accuracy: 0.8262 - val_loss: 1.4302 - val_accuracy: 0.4924
# Epoch 53/100
# 74/74 [==============================] - 44s 598ms/step - loss: 0.3688 - accuracy: 0.8423 - val_loss: 1.5780 - val_accuracy: 0.4686
# Epoch 54/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.3702 - accuracy: 0.8470 - val_loss: 1.4971 - val_accuracy: 0.4720
# Epoch 55/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.3232 - accuracy: 0.8660 - val_loss: 1.7841 - val_accuracy: 0.4975
# Epoch 56/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.3005 - accuracy: 0.8749 - val_loss: 1.6635 - val_accuracy: 0.5059
# Epoch 57/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.2561 - accuracy: 0.8974 - val_loss: 1.8142 - val_accuracy: 0.4635
# Epoch 58/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.2564 - accuracy: 0.8894 - val_loss: 1.8660 - val_accuracy: 0.4720
# Epoch 59/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.2553 - accuracy: 0.8898 - val_loss: 1.8189 - val_accuracy: 0.4975
# Epoch 60/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.2503 - accuracy: 0.8995 - val_loss: 5.3992 - val_accuracy: 0.4975
# Epoch 61/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.6727 - accuracy: 0.7075 - val_loss: 1.0919 - val_accuracy: 0.4431
# Epoch 62/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.7065 - accuracy: 0.6833 - val_loss: 1.2365 - val_accuracy: 0.4143
# Epoch 63/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.8966 - accuracy: 0.5646 - val_loss: 1.0864 - val_accuracy: 0.4092
# Epoch 64/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.7208 - accuracy: 0.6643 - val_loss: 1.1254 - val_accuracy: 0.4295
# Epoch 65/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.5832 - accuracy: 0.7406 - val_loss: 1.5200 - val_accuracy: 0.4992
# Epoch 66/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.4453 - accuracy: 0.8084 - val_loss: 1.5330 - val_accuracy: 0.5195
# Epoch 67/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.3735 - accuracy: 0.8461 - val_loss: 1.4291 - val_accuracy: 0.5246
# Epoch 68/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.2796 - accuracy: 0.8822 - val_loss: 1.7584 - val_accuracy: 0.5025
# Epoch 69/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.2563 - accuracy: 0.8889 - val_loss: 1.7019 - val_accuracy: 0.5008
# Epoch 70/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.2201 - accuracy: 0.9072 - val_loss: 1.9519 - val_accuracy: 0.4992
# Epoch 71/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.2708 - accuracy: 0.8868 - val_loss: 1.4912 - val_accuracy: 0.4975
# Epoch 72/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.4187 - accuracy: 0.8135 - val_loss: 2.4159 - val_accuracy: 0.4109
# Epoch 73/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.3852 - accuracy: 0.8287 - val_loss: 1.9335 - val_accuracy: 0.4194
# Epoch 74/100
# 74/74 [==============================] - 45s 597ms/step - loss: 0.6909 - accuracy: 0.6736 - val_loss: 7.7932 - val_accuracy: 0.3260
# Epoch 75/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.7344 - accuracy: 0.6681 - val_loss: 1.4468 - val_accuracy: 0.4092
# Epoch 76/100
# 74/74 [==============================] - 44s 596ms/step - loss: 0.4758 - accuracy: 0.8109 - val_loss: 1.3920 - val_accuracy: 0.5110
# Epoch 77/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.3104 - accuracy: 0.8682 - val_loss: 1.6295 - val_accuracy: 0.5042
# Epoch 78/100
# 74/74 [==============================] - 45s 597ms/step - loss: 0.2587 - accuracy: 0.8949 - val_loss: 2.4612 - val_accuracy: 0.4958
# Epoch 79/100
# 74/74 [==============================] - 44s 598ms/step - loss: 0.2491 - accuracy: 0.8923 - val_loss: 1.8299 - val_accuracy: 0.5212
# Epoch 80/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.1957 - accuracy: 0.9178 - val_loss: 2.1330 - val_accuracy: 0.4924
# Epoch 81/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.1978 - accuracy: 0.9165 - val_loss: 2.0755 - val_accuracy: 0.4924
# Epoch 82/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.1950 - accuracy: 0.9216 - val_loss: 2.2282 - val_accuracy: 0.4754
# Epoch 83/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.1802 - accuracy: 0.9305 - val_loss: 2.2779 - val_accuracy: 0.4975
# Epoch 84/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.2193 - accuracy: 0.9021 - val_loss: 1.6451 - val_accuracy: 0.4601
# Epoch 85/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.1951 - accuracy: 0.9139 - val_loss: 1.9933 - val_accuracy: 0.5093
# Epoch 86/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.2089 - accuracy: 0.9148 - val_loss: 2.0357 - val_accuracy: 0.5314
# Epoch 87/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.1738 - accuracy: 0.9241 - val_loss: 2.1420 - val_accuracy: 0.5161
# Epoch 88/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.2380 - accuracy: 0.9033 - val_loss: 1.5786 - val_accuracy: 0.5093
# Epoch 89/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.4914 - accuracy: 0.7872 - val_loss: 1.8945 - val_accuracy: 0.3480
# Epoch 90/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.3478 - accuracy: 0.8444 - val_loss: 2.2517 - val_accuracy: 0.4448
# Epoch 91/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.2675 - accuracy: 0.8792 - val_loss: 1.6383 - val_accuracy: 0.5025
# Epoch 92/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.6999 - accuracy: 0.6821 - val_loss: 1.1586 - val_accuracy: 0.3379
# Epoch 93/100
# 74/74 [==============================] - 44s 597ms/step - loss: 0.4588 - accuracy: 0.7965 - val_loss: 1.8857 - val_accuracy: 0.3888
# Epoch 94/100
# 74/74 [==============================] - 45s 598ms/step - loss: 0.3587 - accuracy: 0.8495 - val_loss: 1.4108 - val_accuracy: 0.4550
# Epoch 95/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.5530 - accuracy: 0.7435 - val_loss: 1.6391 - val_accuracy: 0.5144
# Epoch 96/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.3683 - accuracy: 0.8304 - val_loss: 1.7301 - val_accuracy: 0.4907
# Epoch 97/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.2700 - accuracy: 0.8707 - val_loss: 2.0157 - val_accuracy: 0.4924
# Epoch 98/100
# 74/74 [==============================] - 45s 600ms/step - loss: 0.3431 - accuracy: 0.8504 - val_loss: 1.5438 - val_accuracy: 0.5246
# Epoch 99/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.2540 - accuracy: 0.8894 - val_loss: 1.7800 - val_accuracy: 0.4924
# Epoch 100/100
# 74/74 [==============================] - 45s 599ms/step - loss: 0.2298 - accuracy: 0.9063 - val_loss: 2.1208 - val_accuracy: 0.3582

# %%
# save the model so it does not have to be trained again
save_path = os.path.join(GOOGLE_DRIVE_PATH, 'Models')
model.save(os.path.join(save_path, 'se_resnet101'))

# %%
# get accuracy and loss values
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(acc) + 1)

# plot training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()
