# %% [markdown]
# Jupyter notebook used to train the model 'se_resnet152'.
# The setup of the notebook is inspired from what i have used in the IN3060: Computer Vision module.
# I have used Google Colaboratory to train the model.
# Follow the README file for instructions on how to setup the Google Drive file to be able to replicate this.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the project folder
# Example: GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/DeepfakeDetectionFolder'

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'DeepfakeDetectionModel'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['Dataset', 'Code', 'Models', 'resnet34_train.ipynb', 'resnet50_train.ipynb', 'resnet101_train.ipynb', 'resnet152_train.ipynb', 'compare_resnet_models.ipynb', 'se_resnet34_train.ipynb', 'se_resnet50_train.ipynb', 'se_resnet101_train.ipynb', 'Copy of resnet152_train.ipynb']

# %%
# set paths to dataset and code folder
DATASET_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Dataset', 'Dataset_Cropped')
CODE_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Code')
print(os.listdir(DATASET_FOLDER))
print(os.listdir(CODE_FOLDER))
# Out:
# ['.DS_Store', 'train', 'test']
# ['resnet34.py', '__pycache__', 'calculate_mean_std.py', 'resnet50.py', 'resnet152.py', 'resnet101.py', 'se_resnet34.py', 'se_resnet50.py', 'se_resnet101.py', 'se_resnet152.py']

# %%
# necessary to be able to load the functions from the code folder
# %load_ext autoreload
# %autoreload 2

# %%
# append code folder to system
import sys
sys.path.append(CODE_FOLDER)

# %%
# import model and function to calculate mean and std values
from se_resnet152 import Se_ResNet152
from calculate_mean_std import calculate_mean_std

# %%
# setup train dataset path
train_dataset_path = os.path.join(DATASET_FOLDER, 'train')

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# check if cpu or gpu is being used
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
# calcualte average mean and std value to be used after to normalize the training dataset
stats_transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.ToTensor(),
])

stats_dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=stats_transform)

stats_loader = DataLoader(stats_dataset, batch_size=4, shuffle=True, num_workers=2)

calc_mean, calc_std = calculate_mean_std(stats_loader)

print(f'Mean: {calc_mean}')
print(f'Std: {calc_std}')
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Mean: tensor([0.5498, 0.4155, 0.3822])
# Std: tensor([0.2164, 0.1714, 0.1615])

# %%
# apply transformations to the training dataset
transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    transforms.Normalize(mean=calc_mean, std=calc_std),
])

dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=transform)

# split dataset into training and testing using 80/20 split
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="training", seed=123)
# Out:
# Found 2948 files belonging to 3 classes.
# Using 2359 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="validation", seed=123)
# Out:
# Found 2948 files belonging to 3 classes.
# Using 589 files for validation.

# %%
model = Se_ResNet152()

# %%
# declare loss parameter and optimizer used
criterion = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model.compile(optimizer=optimizer, loss=criterion, metrics=['accuracy'])

# %%
# train the model using 100 epochs
num_epochs = 100
history = model.fit(train_ds, epochs=num_epochs, validation_data=val_ds)
# Out:
# Epoch 1/100
# 74/74 [==============================] - 250s 2s/step - loss: 8.5537 - accuracy: 0.3366 - val_loss: 15.9762 - val_accuracy: 0.3413
# Epoch 2/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.5385 - accuracy: 0.3400 - val_loss: 1.1291 - val_accuracy: 0.3497
# Epoch 3/100
# 74/74 [==============================] - 117s 2s/step - loss: 1.2176 - accuracy: 0.3463 - val_loss: 1.1311 - val_accuracy: 0.3497
# Epoch 4/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.1293 - accuracy: 0.3612 - val_loss: 1.1262 - val_accuracy: 0.3480
# Epoch 5/100
# 74/74 [==============================] - 117s 2s/step - loss: 1.0987 - accuracy: 0.3951 - val_loss: 3.2981 - val_accuracy: 0.3311
# Epoch 6/100
# 74/74 [==============================] - 117s 2s/step - loss: 1.0921 - accuracy: 0.3841 - val_loss: 8.7317 - val_accuracy: 0.3701
# Epoch 7/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0600 - accuracy: 0.4315 - val_loss: 1.1017 - val_accuracy: 0.4278
# Epoch 8/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0444 - accuracy: 0.4498 - val_loss: 1.3884 - val_accuracy: 0.4007
# Epoch 9/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0232 - accuracy: 0.4676 - val_loss: 1.3462 - val_accuracy: 0.4516
# Epoch 10/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.9952 - accuracy: 0.4905 - val_loss: 1.1112 - val_accuracy: 0.4550
# Epoch 11/100
# 74/74 [==============================] - 117s 2s/step - loss: 1.0237 - accuracy: 0.4659 - val_loss: 99.3132 - val_accuracy: 0.3786
# Epoch 12/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.9885 - accuracy: 0.5189 - val_loss: 1.8611 - val_accuracy: 0.4737
# Epoch 13/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.9562 - accuracy: 0.5396 - val_loss: 0.9974 - val_accuracy: 0.4907
# Epoch 14/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.9373 - accuracy: 0.5456 - val_loss: 1.0457 - val_accuracy: 0.4533
# Epoch 15/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0945 - accuracy: 0.4214 - val_loss: 14.9043 - val_accuracy: 0.3820
# Epoch 16/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0379 - accuracy: 0.4582 - val_loss: 8.5259 - val_accuracy: 0.4431
# Epoch 17/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0079 - accuracy: 0.4922 - val_loss: 1.0920 - val_accuracy: 0.3854
# Epoch 18/100
# 74/74 [==============================] - 116s 2s/step - loss: 1.0031 - accuracy: 0.5019 - val_loss: 1.0945 - val_accuracy: 0.3803
# Epoch 19/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.9589 - accuracy: 0.5223 - val_loss: 1.1140 - val_accuracy: 0.4448
# Epoch 20/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.9631 - accuracy: 0.5138 - val_loss: 1.0308 - val_accuracy: 0.4278
# Epoch 21/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.9598 - accuracy: 0.5320 - val_loss: 3.1900 - val_accuracy: 0.3718
# Epoch 22/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.9300 - accuracy: 0.5451 - val_loss: 1.2039 - val_accuracy: 0.4635
# Epoch 23/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.8926 - accuracy: 0.5774 - val_loss: 1.0076 - val_accuracy: 0.5008
# Epoch 24/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.8590 - accuracy: 0.5880 - val_loss: 0.9768 - val_accuracy: 0.5076
# Epoch 25/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.8554 - accuracy: 0.5986 - val_loss: 0.9770 - val_accuracy: 0.5195
# Epoch 26/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.8040 - accuracy: 0.6388 - val_loss: 0.9705 - val_accuracy: 0.5263
# Epoch 27/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.8063 - accuracy: 0.6308 - val_loss: 0.9535 - val_accuracy: 0.5110
# Epoch 28/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.7921 - accuracy: 0.6422 - val_loss: 0.9555 - val_accuracy: 0.5603
# Epoch 29/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.7552 - accuracy: 0.6668 - val_loss: 1.0293 - val_accuracy: 0.5263
# Epoch 30/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.7370 - accuracy: 0.6757 - val_loss: 0.9985 - val_accuracy: 0.5382
# Epoch 31/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.7046 - accuracy: 0.6905 - val_loss: 1.4020 - val_accuracy: 0.4873
# Epoch 32/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.7455 - accuracy: 0.6596 - val_loss: 1.0746 - val_accuracy: 0.5467
# Epoch 33/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.6691 - accuracy: 0.7130 - val_loss: 1.0391 - val_accuracy: 0.5671
# Epoch 34/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.6678 - accuracy: 0.7033 - val_loss: 1.0048 - val_accuracy: 0.5654
# Epoch 35/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.6254 - accuracy: 0.7372 - val_loss: 1.1292 - val_accuracy: 0.5144
# Epoch 36/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.5797 - accuracy: 0.7410 - val_loss: 3.7766 - val_accuracy: 0.4618
# Epoch 37/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.5269 - accuracy: 0.7762 - val_loss: 1.0998 - val_accuracy: 0.5823
# Epoch 38/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.4895 - accuracy: 0.8012 - val_loss: 1.1412 - val_accuracy: 0.5637
# Epoch 39/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.5754 - accuracy: 0.7588 - val_loss: 1.6509 - val_accuracy: 0.5144
# Epoch 40/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.4751 - accuracy: 0.8012 - val_loss: 3.9160 - val_accuracy: 0.4584
# Epoch 41/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.4448 - accuracy: 0.8131 - val_loss: 1.3871 - val_accuracy: 0.5229
# Epoch 42/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.4244 - accuracy: 0.8224 - val_loss: 1.3458 - val_accuracy: 0.5314
# Epoch 43/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3842 - accuracy: 0.8499 - val_loss: 1.9840 - val_accuracy: 0.5314
# Epoch 44/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3535 - accuracy: 0.8567 - val_loss: 1.4376 - val_accuracy: 0.5399
# Epoch 45/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.3606 - accuracy: 0.8571 - val_loss: 1.4022 - val_accuracy: 0.5127
# Epoch 46/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3260 - accuracy: 0.8686 - val_loss: 3.5097 - val_accuracy: 0.5195
# Epoch 47/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3286 - accuracy: 0.8703 - val_loss: 1.4302 - val_accuracy: 0.5348
# Epoch 48/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3173 - accuracy: 0.8800 - val_loss: 1.9100 - val_accuracy: 0.4890
# Epoch 49/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2606 - accuracy: 0.8995 - val_loss: 1.7145 - val_accuracy: 0.5127
# Epoch 50/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2758 - accuracy: 0.8940 - val_loss: 1.3902 - val_accuracy: 0.5823
# Epoch 51/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2493 - accuracy: 0.9076 - val_loss: 1.5952 - val_accuracy: 0.5433
# Epoch 52/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2430 - accuracy: 0.9038 - val_loss: 1.6350 - val_accuracy: 0.5348
# Epoch 53/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2833 - accuracy: 0.8834 - val_loss: 1.4982 - val_accuracy: 0.5552
# Epoch 54/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.2664 - accuracy: 0.8915 - val_loss: 1.5196 - val_accuracy: 0.5739
# Epoch 55/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2745 - accuracy: 0.8834 - val_loss: 3.4651 - val_accuracy: 0.4856
# Epoch 56/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.2805 - accuracy: 0.8843 - val_loss: 1.6292 - val_accuracy: 0.5518
# Epoch 57/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2984 - accuracy: 0.8830 - val_loss: 1.5082 - val_accuracy: 0.4720
# Epoch 58/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3416 - accuracy: 0.8639 - val_loss: 1.3289 - val_accuracy: 0.5552
# Epoch 59/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3905 - accuracy: 0.8381 - val_loss: 1.1561 - val_accuracy: 0.5535
# Epoch 60/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3110 - accuracy: 0.8762 - val_loss: 1.3954 - val_accuracy: 0.5671
# Epoch 61/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.3366 - accuracy: 0.8703 - val_loss: 18.4828 - val_accuracy: 0.4177
# Epoch 62/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2736 - accuracy: 0.8906 - val_loss: 1.4749 - val_accuracy: 0.5161
# Epoch 63/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2704 - accuracy: 0.8915 - val_loss: 1.8709 - val_accuracy: 0.5399
# Epoch 64/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2570 - accuracy: 0.8957 - val_loss: 1.6299 - val_accuracy: 0.5178
# Epoch 65/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1655 - accuracy: 0.9313 - val_loss: 1.7040 - val_accuracy: 0.5433
# Epoch 66/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1489 - accuracy: 0.9436 - val_loss: 1.9099 - val_accuracy: 0.5569
# Epoch 67/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1331 - accuracy: 0.9491 - val_loss: 1.8612 - val_accuracy: 0.5925
# Epoch 68/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1270 - accuracy: 0.9491 - val_loss: 1.9992 - val_accuracy: 0.5569
# Epoch 69/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1591 - accuracy: 0.9385 - val_loss: 1.8897 - val_accuracy: 0.5603
# Epoch 70/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1238 - accuracy: 0.9491 - val_loss: 2.0480 - val_accuracy: 0.5518
# Epoch 71/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1082 - accuracy: 0.9597 - val_loss: 2.0377 - val_accuracy: 0.5382
# Epoch 72/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.0979 - accuracy: 0.9635 - val_loss: 2.3490 - val_accuracy: 0.5450
# Epoch 73/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1184 - accuracy: 0.9563 - val_loss: 2.1510 - val_accuracy: 0.5603
# Epoch 74/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1574 - accuracy: 0.9385 - val_loss: 2.2414 - val_accuracy: 0.5467
# Epoch 75/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1351 - accuracy: 0.9462 - val_loss: 1.9925 - val_accuracy: 0.5535
# Epoch 76/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1327 - accuracy: 0.9496 - val_loss: 1.9963 - val_accuracy: 0.5705
# Epoch 77/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1040 - accuracy: 0.9610 - val_loss: 2.0003 - val_accuracy: 0.5908
# Epoch 78/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1150 - accuracy: 0.9529 - val_loss: 3.9247 - val_accuracy: 0.4890
# Epoch 79/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1500 - accuracy: 0.9423 - val_loss: 1.8249 - val_accuracy: 0.5637
# Epoch 80/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2105 - accuracy: 0.9207 - val_loss: 1.7311 - val_accuracy: 0.5280
# Epoch 81/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2576 - accuracy: 0.8991 - val_loss: 51.4560 - val_accuracy: 0.3480
# Epoch 82/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.9125 - accuracy: 0.5638 - val_loss: 2.0355 - val_accuracy: 0.4890
# Epoch 83/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.4907 - accuracy: 0.7842 - val_loss: 1.2147 - val_accuracy: 0.5484
# Epoch 84/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.2648 - accuracy: 0.8885 - val_loss: 1.5010 - val_accuracy: 0.5110
# Epoch 85/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1968 - accuracy: 0.9152 - val_loss: 1.6810 - val_accuracy: 0.5501
# Epoch 86/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1980 - accuracy: 0.9186 - val_loss: 2.1047 - val_accuracy: 0.5127
# Epoch 87/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1689 - accuracy: 0.9309 - val_loss: 1.8235 - val_accuracy: 0.5654
# Epoch 88/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1268 - accuracy: 0.9453 - val_loss: 2.0203 - val_accuracy: 0.5535
# Epoch 89/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1106 - accuracy: 0.9538 - val_loss: 1.9094 - val_accuracy: 0.5433
# Epoch 90/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1130 - accuracy: 0.9538 - val_loss: 2.1060 - val_accuracy: 0.5569
# Epoch 91/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1373 - accuracy: 0.9381 - val_loss: 1.9601 - val_accuracy: 0.5569
# Epoch 92/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1392 - accuracy: 0.9407 - val_loss: 1.9248 - val_accuracy: 0.5756
# Epoch 93/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1094 - accuracy: 0.9576 - val_loss: 2.0854 - val_accuracy: 0.5620
# Epoch 94/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.0869 - accuracy: 0.9640 - val_loss: 2.5968 - val_accuracy: 0.5416
# Epoch 95/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1915 - accuracy: 0.9296 - val_loss: 1.1815 - val_accuracy: 0.5246
# Epoch 96/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1725 - accuracy: 0.9351 - val_loss: 1.7778 - val_accuracy: 0.5450
# Epoch 97/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1049 - accuracy: 0.9606 - val_loss: 2.1903 - val_accuracy: 0.5535
# Epoch 98/100
# 74/74 [==============================] - 117s 2s/step - loss: 0.1196 - accuracy: 0.9525 - val_loss: 2.0676 - val_accuracy: 0.5467
# Epoch 99/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1278 - accuracy: 0.9513 - val_loss: 4.2274 - val_accuracy: 0.4482
# Epoch 100/100
# 74/74 [==============================] - 116s 2s/step - loss: 0.1133 - accuracy: 0.9534 - val_loss: 2.2342 - val_accuracy: 0.5076

# %%
# save the model so it does not have to be trained again
save_path = os.path.join(GOOGLE_DRIVE_PATH, 'Models')
model.save(os.path.join(save_path, 'se_resnet152'))

# %%
# get accuracy and loss values
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(acc) + 1)

# plot training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()
